# %% [markdown]
# <a href="https://colab.research.google.com/github/jchen6727/colab/blob/master/pubtk1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tutorial 1**
#
# **Note 0** This tutorial will set use the `pubtk` from tutorial 1 with socket communication features

# %%
#jupyter 0
from google.colab import drive # use drive.mount() to link Google Drive to
drive.mount('/content/drive')  # the google colab session
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Note 1** since we've created the virtual environment in the first tutorial, now we can just link the `site-packages` to have access to our custom python environment

# %%
#jupyter 1
import site
site.addsitedir('/content/drive/MyDrive/venv/lib/python3.10/site-packages')

# %% [markdown]
# **Note 2** This time we'll focus on the **INET_Dispatcher** which uses `INET` (TCP) to communicate with the host. Let's inherit the `INET_Dispatcher` and an example `Submit`, the one that handles sockets on the `ZSH` environment.

# %%
#jupyter 2
from pubtk.runtk import INET_Dispatcher, Submit, ZSHSubmitSOCK, Template
print(ZSHSubmitSOCK())
# Out:
# submit:
# zsh {cwd}/{label}.sh
#
# path:
# #!/bin/zsh
# cd {cwd}
# export SOCNAME="{sockname}"
# export JOBID=$$
# {env}
# nohup {command} > {cwd}/{label}.run &
# pid=$!
# echo $pid >&1
#
#
# script:
# {cwd}/{label}.sh

# %% [markdown]
# **Note 3** Notice the important line:
# ```
# export SOCNAME="{sockname}"
# ```
# this is what we can use to establish the socket address which the `Dispatcher` and `Runner` can communicate through.
#
# Let's extend the `Submit` with a new `class` that extends functionality to allow for `socket` communication on `Google Colab`
#
# For reference, here is our old code:
# ```
# class GCSubmit(Submit):
#   def __init__(self):
#     # creates a Submit with the templates we define
#     super().__init__(
#         submit_template = Template("sh {cwd}/{label}.sh"),
#         script_template = Template("""\
# #!/bin/bash
# export FOO={foovalue}
# export BAR={barvalue}
# export BAZ={bazvalue}
# {env}
# nohup /content/drive/MyDrive/venv/bin/python /content/drive/MyDrive/dev/runner.py > {cwd}/{label}.run &
# pid=$!
# echo $pid >&1
# """
#         )
#     )
#   def submit_job(self):
#     # using this submit_job, we can add some handling of stdout, job failure (i.e. if stdout does not return an integer value as expected),
#     # extending the functionality of Submit with this exception handling.
#     proc = super().submit_job()
#     try:
#       self.job_id = int(proc.stdout)
#     except Exception as e:
#       raise(Exception("{}\nJob submission failed:\n{}\n{}\n{}\n{}".format(e, self.submit, self.script, proc.stdout, proc.stderr)))
#     return self.job_id
# ```

# %%
#jupyter 3
class GCSubmitSOCK(Submit):
  def __init__(self):
    # creates a Submit with the templates we define
    super().__init__(
        submit_template = Template("sh {cwd}/{label}.sh"),
        script_template = Template("""\
#!/bin/bash
export SOCNAME="{sockname}"
{env}
nohup /content/drive/MyDrive/venv/bin/python /content/drive/MyDrive/dev/runner.py > {cwd}/{label}.run &
pid=$!
echo $pid >&1
"""
        )
    )
  def submit_job(self):
    # using this submit_job, we can add some handling of stdout, job failure (i.e. if stdout does not return an integer value as expected),
    # extending the functionality of Submit with this exception handling.
    proc = super().submit_job()
    try:
      self.job_id = int(proc.stdout)
    except Exception as e:
      raise(Exception("{}\nJob submission failed:\n{}\n{}\n{}\n{}".format(e, self.submit, self.script, proc.stdout, proc.stderr)))
    return self.job_id

gcs = GCSubmitSOCK()

# %% [markdown]
# **Note 4** N.B, the `socname={sockname}` provides a field that the INET_Dispatcher can fill as it requests a TCP port for communication. This happens at job creation

# %% [markdown]
# **Note 5** Now we can pass the custom submission to our **INET_Dispatcher** which extends the base **SH_Dispatcher** with support for communication.

# %%
#jupyter 5
dispatcher = INET_Dispatcher(cwd='/content', submit=gcs, gid='sock_example')
print(dispatcher.submit) # prints the dispatcher.submit
# Out:
# submit:
# sh {cwd}/{label}.sh
#
# path:
# #!/bin/bash
# export SOCNAME="{sockname}"
# {env}
# nohup /content/drive/MyDrive/venv/bin/python /content/drive/MyDrive/dev/runner.py > {cwd}/{label}.run &
# pid=$!
# echo $pid >&1
#
#
# script:
# {cwd}/{label}.sh

# %% [markdown]
# **Note 6** To pass arguments to the **Runner** script, we will call `update_env` from the dispatcher. The argument is a dictionary of `key:value` pairs. Additionally, we can update the arbitrary `FOO`, `BAR` and `BAZ` values from the `dispatcher.submit`

# %%
#jupyter 6
dispatcher.update_env({'strvalue': '1',
                       'intvalue': 2,
                       'fltvalue': 3.0})
print(dispatcher.submit)
# Out:
# submit:
# sh {cwd}/{label}.sh
#
# path:
# #!/bin/bash
# export SOCNAME="{sockname}"
# {env}
# nohup /content/drive/MyDrive/venv/bin/python /content/drive/MyDrive/dev/runner.py > {cwd}/{label}.run &
# pid=$!
# echo $pid >&1
#
#
# script:
# {cwd}/{label}.sh

# %% [markdown]
# **Note 7** Upon job creation, the `{env}`, `{cwd}` and `{label}` are filled.
#
# the `{env}` will be replaced with a custom `serialization` (in this case, exported string values) that can then be deserialized by the **runner** in the `runner.py` script

# %%
#jupyter 7
dispatcher.create_job()
print(dispatcher.submit) # see the new submit
# Out:
# submit:
# sh /content/example.sh
#
# path:
# #!/bin/bash
# export SOCNAME="('172.28.0.12', 55501)"
#
# export STRRUNTK3="strvalue=1"
# export INTRUNTK4="intvalue=2"
# export FLOATRUNTK5="fltvalue=3.0"
# nohup /content/drive/MyDrive/venv/bin/python /content/drive/MyDrive/dev/runner.py > /content/example.run &
# pid=$!
# echo $pid >&1
#
#
# script:
# /content/example.sh

# %% [markdown]
# **Note 8** Let's download and check a basic `runner.py` using the `Runner` class.

# %%
#jupyter 8
# !rm /content/drive/MyDrive/dev/runner.py

# !cat /content/drive/MyDrive/dev/runner.py
# Out:
# from pubtk.runtk import SocketRunner
# import os, sys, json
#
# print(os.getpid())
#
# runner = SocketRunner()
#
# mappings = json.dumps(runner.mappings)
#
# runner.connect()
# runner.send(mappings)
# print(mappings)

# %% [markdown]
# **Note 9** This new runner is similar to the one in the `pubtk0.ipynb`. Of note, it also calls a connect in order to establish communication with the `SOCNAME` TCP port, and finally calls `runner.close()` in order to deallocate the opened socket.
#
# On the same end, the `dispatcher` also calls a `dispatcher.clean` to deallocate the opened socket.
#
# N.B. generally sockets are deallocated with the completion of the function. We can use `lsof` to check this; however, it is considered good programming practice to `deallocate` and `free` resources when they are no longer in use...

# %%
#jupyter 9
dispatcher.submit_job()
connection, runner_address = dispatcher.accept()
recv_message = dispatcher.recv()
dispatcher.job_id # prints the job_id, should match the printed pid from the runner.py script
connection, runner_address
recv_message
dispatcher.clean([])
# Out:
# '{"fltvalue": 3.0, "strvalue": "1", "intvalue": 2}'

# %%
# !lsof
# Out:
# Streaming output truncated to the last 5000 lines.
# drive     1011 1028 drive     root    3w      REG               0,51     4780 1310800 /tmp/drive.e8229860d1c1.root.log.INFO.20240220-140447.1011
# drive     1011 1028 drive     root    4w      REG               0,51     1253 1310799 /root/.config/Google/DriveFS/Logs/parent.txt
# drive     1011 1028 drive     root    5w      REG               0,51   109122 1310801 /root/.config/Google/DriveFS/Logs/drive_fs.txt
# drive     1011 1028 drive     root    6r     FIFO               0,13      0t0   41181 pipe
# drive     1011 1028 drive     root    7w     FIFO               0,13      0t0   41181 pipe
# drive     1011 1028 drive     root    8ur     REG               0,51    12288 1310795 /root/.config/Google/DriveFS/metrics_store_sqlite.db
# drive     1011 1028 drive     root    9u      REG               0,51    20632 1310816 /root/.config/Google/DriveFS/metrics_store_sqlite.db-wal
# drive     1011 1028 drive     root   10ur     REG               0,51    32768 1310820 /root/.config/Google/DriveFS/metrics_store_sqlite.db-shm
# drive     1011 1028 drive     root   11r     FIFO               0,13      0t0   41182 pipe
# drive     1011 1028 drive     root   12w     FIFO               0,13      0t0   41182 pipe
# drive     1011 1028 drive     root   13w     FIFO               0,13      0t0   39929 pipe
# drive     1011 1028 drive     root   14r     FIFO               0,13      0t0   41183 pipe
# drive     1011 1028 drive     root   15u     unix 0x0000000000000000      0t0   41185 /tmp/drivefs_ipc.0 type=STREAM
# drive     1011 1028 drive     root   16r     FIFO               0,13      0t0   41186 pipe
# drive     1011 1028 drive     root   17w     FIFO               0,13      0t0   41186 pipe
# drive     1011 1028 drive     root   18r     FIFO               0,13      0t0   41187 pipe
# drive     1011 1028 drive     root   19w     FIFO               0,13      0t0   41187 pipe
# drive     1011 1028 drive     root   20ur     REG               0,51    36864 1310797 /root/.config/Google/DriveFS/root_preference_sqlite.db
# drive     1011 1028 drive     root   21u      REG               0,51        0 1310821 /root/.config/Google/DriveFS/root_preference_sqlite.db-wal
# drive     1011 1028 drive     root   22ur     REG               0,51    32768 1310891 /root/.config/Google/DriveFS/root_preference_sqlite.db-shm
# drive     1011 1028 drive     root   23u  a_inode               0,14        0      18 [eventpoll]
# drive     1011 1028 drive     root   24u     unix 0x0000000000000000      0t0   41203 /tmp/drivefs_ipc.0_shell type=STREAM
# drive     1011 1028 drive     root   26ur     REG               0,51    53248 1310803 /root/.config/Google/DriveFS/experiments.db
# drive     1011 1028 drive     root   28u     IPv4             310190      0t0     TCP e8229860d1c1:41454->pl-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1028 drive     root   29r     FIFO               0,13      0t0   41210 pipe
# drive     1011 1028 drive     root   30w     FIFO               0,13      0t0   41210 pipe
# drive     1011 1028 drive     root   31w      REG               0,51     1911 1310892 /tmp/drive.e8229860d1c1.root.log.WARNING.20240220-140447.1011
# drive     1011 1028 drive     root   32w      REG               0,51     1911 1310900 /tmp/drive.e8229860d1c1.root.log.ERROR.20240220-140447.1011
# drive     1011 1028 drive     root   33u     unix 0x0000000000000000      0t0   42135 type=STREAM
# drive     1011 1028 drive     root   34u     unix 0x0000000000000000      0t0   42136 type=STREAM
# drive     1011 1028 drive     root   35u     IPv4              42137      0t0     TCP e8229860d1c1:40968->172.28.0.1:8009 (ESTABLISHED)
# drive     1011 1028 drive     root   36ur     REG               0,51    12288 1310814 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db
# drive     1011 1028 drive     root   37u      REG               0,51  1977632 1310903 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-wal
# drive     1011 1028 drive     root   38r     FIFO               0,13      0t0   41223 pipe
# drive     1011 1028 drive     root   39w     FIFO               0,13      0t0   41223 pipe
# drive     1011 1028 drive     root   40ur     REG               0,51    32768 1310904 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-shm
# drive     1011 1028 drive     root   41ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1028 drive     root   42ur     REG               0,51     8192 1310819 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db
# drive     1011 1028 drive     root   43u      REG               0,51   329632 1310907 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-wal
# drive     1011 1028 drive     root   44ur     REG               0,51    32768 1310911 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-shm
# drive     1011 1028 drive     root   45ur     REG               0,51     8192 1310890 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db
# drive     1011 1028 drive     root   46u      REG               0,51     4152 1310912 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-wal
# drive     1011 1028 drive     root   47ur     REG               0,51    32768 1310914 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-shm
# drive     1011 1028 drive     root   48u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1028 drive     root   49ur     REG               0,51    32768 1310915 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-shm
# drive     1011 1028 drive     root   50ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1028 drive     root   51u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1028 drive     root   52ur     REG               0,51    12288 1310902 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter
# drive     1011 1028 drive     root   53u      REG               0,51    41232 1310917 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-wal
# drive     1011 1028 drive     root   54ur     REG               0,51    32768 1310918 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-shm
# drive     1011 1028 drive     root   55ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1028 drive     root   56u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1028 drive     root   57ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1028 drive     root   58u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1028 drive     root   59ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1028 drive     root   60u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1028 drive     root   61ur     REG               0,51    12288 1310902 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter
# drive     1011 1028 drive     root   62u      REG               0,51    41232 1310917 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-wal
# drive     1011 1028 drive     root   63ur     REG               0,51    28672 1310905 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db
# drive     1011 1028 drive     root   64u      REG               0,51        0 1310920 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-wal
# drive     1011 1028 drive     root   65ur     REG               0,51    32768 1310921 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-shm
# drive     1011 1028 drive     root   66ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1028 drive     root   67r  a_inode               0,14        0      18 inotify
# drive     1011 1028 drive     root   68ur     REG               0,51    77824 1310910 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db
# drive     1011 1028 drive     root   69u      REG               0,51        0 1310927 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-wal
# drive     1011 1028 drive     root   70ur     REG               0,51    32768 1310928 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-shm
# drive     1011 1028 drive     root   71ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1028 drive     root   72u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1028 drive     root   73ur     REG               0,51    32768 1310930 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-shm
# drive     1011 1028 drive     root   74ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1028 drive     root   75u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1028 drive     root   76ur     REG               0,51    12288 1310916 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter
# drive     1011 1028 drive     root   77u      REG               0,51    16512 1310931 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-wal
# drive     1011 1028 drive     root   78ur     REG               0,51    32768 1310932 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-shm
# drive     1011 1028 drive     root   79ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1028 drive     root   80u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1028 drive     root   81ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1028 drive     root   82u     unix 0x0000000000000000      0t0   42204 type=STREAM
# drive     1011 1028 drive     root   83u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1028 drive     root   84ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1028 drive     root   85u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1028 drive     root   86ur     REG               0,51    12288 1310916 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter
# drive     1011 1028 drive     root   87u      REG               0,51    16512 1310931 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-wal
# drive     1011 1028 drive     root   88ur     REG               0,51    28672 1310919 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db
# drive     1011 1028 drive     root   89u      REG               0,51        0 1310933 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-wal
# drive     1011 1028 drive     root   90ur     REG               0,51    32768 1310934 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-shm
# drive     1011 1028 drive     root   91u     unix 0x0000000000000000      0t0   42205 type=STREAM
# drive     1011 1028 drive     root   92u     IPv4             310206      0t0     TCP e8229860d1c1:50754->py-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1028 drive     root   93u      CHR             10,229      0t0      11 /dev/fuse
# drive     1011 1028 drive     root   94ur     REG               0,51    77824 1310910 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db
# drive     1011 1028 drive     root   95u      REG               0,51        0 1310927 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-wal
# drive     1011 1028 drive     root   96u     unix 0x0000000000000000      0t0   42284 type=STREAM
# drive     1011 1028 drive     root   97u     unix 0x0000000000000000      0t0   42285 type=STREAM
# drive     1011 1028 drive     root   98u     IPv4             310221      0t0     TCP e8229860d1c1:38710->pf-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1028 drive     root  104u     unix 0x0000000000000000      0t0   44806 type=STREAM
# drive     1011 1028 drive     root  112u     unix 0x0000000000000000      0t0   44807 type=STREAM
# drive     1011 1028 drive     root  114u     unix 0x0000000000000000      0t0   43871 type=STREAM
# drive     1011 1028 drive     root  115u     unix 0x0000000000000000      0t0   43872 type=STREAM
# drive     1011 1028 drive     root  117u     IPv4              43915      0t0     TCP e8229860d1c1:46136->pj-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1036 drive     root  cwd       DIR               0,51     4096 4325382 /content
# drive     1011 1036 drive     root  rtd       DIR               0,51     4096 1310732 /
# drive     1011 1036 drive     root  txt       REG               0,51 62395184 1441811 /opt/google/drive/drive
# drive     1011 1036 drive     root  mem       REG                7,0          1441811 /opt/google/drive/drive (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310934 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310932 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310930 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310928 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310921 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310918 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310915 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310914 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310911 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310904 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310891 /root/.config/Google/DriveFS/root_preference_sqlite.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1310820 /root/.config/Google/DriveFS/metrics_store_sqlite.db-shm (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1603426 /usr/lib/x86_64-linux-gnu/libc.so.6 (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1604620 /usr/lib/x86_64-linux-gnu/librt.so.1 (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1603514 /usr/lib/x86_64-linux-gnu/libdl.so.2 (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1604575 /usr/lib/x86_64-linux-gnu/libpthread.so.0 (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1604006 /usr/lib/x86_64-linux-gnu/libm.so.6 (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1441813 /opt/google/drive/libfuse.so (path dev=0,51)
# drive     1011 1036 drive     root  mem       REG                7,0          1603060 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2 (path dev=0,51)
# drive     1011 1036 drive     root    0r      CHR                1,3      0t0       5 /dev/null
# drive     1011 1036 drive     root    1w     FIFO               0,13      0t0   39929 pipe
# drive     1011 1036 drive     root    2w     FIFO               0,13      0t0   41183 pipe
# drive     1011 1036 drive     root    3w      REG               0,51     4780 1310800 /tmp/drive.e8229860d1c1.root.log.INFO.20240220-140447.1011
# drive     1011 1036 drive     root    4w      REG               0,51     1253 1310799 /root/.config/Google/DriveFS/Logs/parent.txt
# drive     1011 1036 drive     root    5w      REG               0,51   109122 1310801 /root/.config/Google/DriveFS/Logs/drive_fs.txt
# drive     1011 1036 drive     root    6r     FIFO               0,13      0t0   41181 pipe
# drive     1011 1036 drive     root    7w     FIFO               0,13      0t0   41181 pipe
# drive     1011 1036 drive     root    8ur     REG               0,51    12288 1310795 /root/.config/Google/DriveFS/metrics_store_sqlite.db
# drive     1011 1036 drive     root    9u      REG               0,51    20632 1310816 /root/.config/Google/DriveFS/metrics_store_sqlite.db-wal
# drive     1011 1036 drive     root   10ur     REG               0,51    32768 1310820 /root/.config/Google/DriveFS/metrics_store_sqlite.db-shm
# drive     1011 1036 drive     root   11r     FIFO               0,13      0t0   41182 pipe
# drive     1011 1036 drive     root   12w     FIFO               0,13      0t0   41182 pipe
# drive     1011 1036 drive     root   13w     FIFO               0,13      0t0   39929 pipe
# drive     1011 1036 drive     root   14r     FIFO               0,13      0t0   41183 pipe
# drive     1011 1036 drive     root   15u     unix 0x0000000000000000      0t0   41185 /tmp/drivefs_ipc.0 type=STREAM
# drive     1011 1036 drive     root   16r     FIFO               0,13      0t0   41186 pipe
# drive     1011 1036 drive     root   17w     FIFO               0,13      0t0   41186 pipe
# drive     1011 1036 drive     root   18r     FIFO               0,13      0t0   41187 pipe
# drive     1011 1036 drive     root   19w     FIFO               0,13      0t0   41187 pipe
# drive     1011 1036 drive     root   20ur     REG               0,51    36864 1310797 /root/.config/Google/DriveFS/root_preference_sqlite.db
# drive     1011 1036 drive     root   21u      REG               0,51        0 1310821 /root/.config/Google/DriveFS/root_preference_sqlite.db-wal
# drive     1011 1036 drive     root   22ur     REG               0,51    32768 1310891 /root/.config/Google/DriveFS/root_preference_sqlite.db-shm
# drive     1011 1036 drive     root   23u  a_inode               0,14        0      18 [eventpoll]
# drive     1011 1036 drive     root   24u     unix 0x0000000000000000      0t0   41203 /tmp/drivefs_ipc.0_shell type=STREAM
# drive     1011 1036 drive     root   26ur     REG               0,51    53248 1310803 /root/.config/Google/DriveFS/experiments.db
# drive     1011 1036 drive     root   28u     IPv4             310190      0t0     TCP e8229860d1c1:41454->pl-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1036 drive     root   29r     FIFO               0,13      0t0   41210 pipe
# drive     1011 1036 drive     root   30w     FIFO               0,13      0t0   41210 pipe
# drive     1011 1036 drive     root   31w      REG               0,51     1911 1310892 /tmp/drive.e8229860d1c1.root.log.WARNING.20240220-140447.1011
# drive     1011 1036 drive     root   32w      REG               0,51     1911 1310900 /tmp/drive.e8229860d1c1.root.log.ERROR.20240220-140447.1011
# drive     1011 1036 drive     root   33u     unix 0x0000000000000000      0t0   42135 type=STREAM
# drive     1011 1036 drive     root   34u     unix 0x0000000000000000      0t0   42136 type=STREAM
# drive     1011 1036 drive     root   35u     IPv4              42137      0t0     TCP e8229860d1c1:40968->172.28.0.1:8009 (ESTABLISHED)
# drive     1011 1036 drive     root   36ur     REG               0,51    12288 1310814 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db
# drive     1011 1036 drive     root   37u      REG               0,51  1977632 1310903 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-wal
# drive     1011 1036 drive     root   38r     FIFO               0,13      0t0   41223 pipe
# drive     1011 1036 drive     root   39w     FIFO               0,13      0t0   41223 pipe
# drive     1011 1036 drive     root   40ur     REG               0,51    32768 1310904 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-shm
# drive     1011 1036 drive     root   41ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1036 drive     root   42ur     REG               0,51     8192 1310819 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db
# drive     1011 1036 drive     root   43u      REG               0,51   329632 1310907 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-wal
# drive     1011 1036 drive     root   44ur     REG               0,51    32768 1310911 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-shm
# drive     1011 1036 drive     root   45ur     REG               0,51     8192 1310890 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db
# drive     1011 1036 drive     root   46u      REG               0,51     4152 1310912 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-wal
# drive     1011 1036 drive     root   47ur     REG               0,51    32768 1310914 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-shm
# drive     1011 1036 drive     root   48u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1036 drive     root   49ur     REG               0,51    32768 1310915 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-shm
# drive     1011 1036 drive     root   50ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1036 drive     root   51u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1036 drive     root   52ur     REG               0,51    12288 1310902 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter
# drive     1011 1036 drive     root   53u      REG               0,51    41232 1310917 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-wal
# drive     1011 1036 drive     root   54ur     REG               0,51    32768 1310918 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-shm
# drive     1011 1036 drive     root   55ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1036 drive     root   56u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1036 drive     root   57ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1036 drive     root   58u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1036 drive     root   59ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1036 drive     root   60u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1036 drive     root   61ur     REG               0,51    12288 1310902 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter
# drive     1011 1036 drive     root   62u      REG               0,51    41232 1310917 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-wal
# drive     1011 1036 drive     root   63ur     REG               0,51    28672 1310905 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db
# drive     1011 1036 drive     root   64u      REG               0,51        0 1310920 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-wal
# drive     1011 1036 drive     root   65ur     REG               0,51    32768 1310921 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-shm
# drive     1011 1036 drive     root   66ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1036 drive     root   67r  a_inode               0,14        0      18 inotify
# drive     1011 1036 drive     root   68ur     REG               0,51    77824 1310910 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db
# drive     1011 1036 drive     root   69u      REG               0,51        0 1310927 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-wal
# drive     1011 1036 drive     root   70ur     REG               0,51    32768 1310928 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-shm
# drive     1011 1036 drive     root   71ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1036 drive     root   72u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1036 drive     root   73ur     REG               0,51    32768 1310930 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-shm
# drive     1011 1036 drive     root   74ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1036 drive     root   75u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1036 drive     root   76ur     REG               0,51    12288 1310916 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter
# drive     1011 1036 drive     root   77u      REG               0,51    16512 1310931 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-wal
# drive     1011 1036 drive     root   78ur     REG               0,51    32768 1310932 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-shm
# drive     1011 1036 drive     root   79ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1036 drive     root   80u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1036 drive     root   81ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1036 drive     root   82u     unix 0x0000000000000000      0t0   42204 type=STREAM
# drive     1011 1036 drive     root   83u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1036 drive     root   84ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1036 drive     root   85u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1036 drive     root   86ur     REG               0,51    12288 1310916 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter
# drive     1011 1036 drive     root   87u      REG               0,51    16512 1310931 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-wal
# drive     1011 1036 drive     root   88ur     REG               0,51    28672 1310919 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db
# drive     1011 1036 drive     root   89u      REG               0,51        0 1310933 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-wal
# drive     1011 1036 drive     root   90ur     REG               0,51    32768 1310934 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-shm
# drive     1011 1036 drive     root   91u     unix 0x0000000000000000      0t0   42205 type=STREAM
# drive     1011 1036 drive     root   92u     IPv4             310206      0t0     TCP e8229860d1c1:50754->py-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1036 drive     root   93u      CHR             10,229      0t0      11 /dev/fuse
# drive     1011 1036 drive     root   94ur     REG               0,51    77824 1310910 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db
# drive     1011 1036 drive     root   95u      REG               0,51        0 1310927 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-wal
# drive     1011 1036 drive     root   96u     unix 0x0000000000000000      0t0   42284 type=STREAM
# drive     1011 1036 drive     root   97u     unix 0x0000000000000000      0t0   42285 type=STREAM
# drive     1011 1036 drive     root   98u     IPv4             310221      0t0     TCP e8229860d1c1:38710->pf-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1036 drive     root  104u     unix 0x0000000000000000      0t0   44806 type=STREAM
# drive     1011 1036 drive     root  112u     unix 0x0000000000000000      0t0   44807 type=STREAM
# drive     1011 1036 drive     root  114u     unix 0x0000000000000000      0t0   43871 type=STREAM
# drive     1011 1036 drive     root  115u     unix 0x0000000000000000      0t0   43872 type=STREAM
# drive     1011 1036 drive     root  117u     IPv4              43915      0t0     TCP e8229860d1c1:46136->pj-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1037 drive     root  cwd       DIR               0,51     4096 4325382 /content
# drive     1011 1037 drive     root  rtd       DIR               0,51     4096 1310732 /
# drive     1011 1037 drive     root  txt       REG               0,51 62395184 1441811 /opt/google/drive/drive
# drive     1011 1037 drive     root  mem       REG                7,0          1441811 /opt/google/drive/drive (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310934 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310932 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310930 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310928 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310921 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310918 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310915 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310914 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310911 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310904 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310891 /root/.config/Google/DriveFS/root_preference_sqlite.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1310820 /root/.config/Google/DriveFS/metrics_store_sqlite.db-shm (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1603426 /usr/lib/x86_64-linux-gnu/libc.so.6 (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1604620 /usr/lib/x86_64-linux-gnu/librt.so.1 (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1603514 /usr/lib/x86_64-linux-gnu/libdl.so.2 (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1604575 /usr/lib/x86_64-linux-gnu/libpthread.so.0 (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1604006 /usr/lib/x86_64-linux-gnu/libm.so.6 (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1441813 /opt/google/drive/libfuse.so (path dev=0,51)
# drive     1011 1037 drive     root  mem       REG                7,0          1603060 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2 (path dev=0,51)
# drive     1011 1037 drive     root    0r      CHR                1,3      0t0       5 /dev/null
# drive     1011 1037 drive     root    1w     FIFO               0,13      0t0   39929 pipe
# drive     1011 1037 drive     root    2w     FIFO               0,13      0t0   41183 pipe
# drive     1011 1037 drive     root    3w      REG               0,51     4780 1310800 /tmp/drive.e8229860d1c1.root.log.INFO.20240220-140447.1011
# drive     1011 1037 drive     root    4w      REG               0,51     1253 1310799 /root/.config/Google/DriveFS/Logs/parent.txt
# drive     1011 1037 drive     root    5w      REG               0,51   109122 1310801 /root/.config/Google/DriveFS/Logs/drive_fs.txt
# drive     1011 1037 drive     root    6r     FIFO               0,13      0t0   41181 pipe
# drive     1011 1037 drive     root    7w     FIFO               0,13      0t0   41181 pipe
# drive     1011 1037 drive     root    8ur     REG               0,51    12288 1310795 /root/.config/Google/DriveFS/metrics_store_sqlite.db
# drive     1011 1037 drive     root    9u      REG               0,51    20632 1310816 /root/.config/Google/DriveFS/metrics_store_sqlite.db-wal
# drive     1011 1037 drive     root   10ur     REG               0,51    32768 1310820 /root/.config/Google/DriveFS/metrics_store_sqlite.db-shm
# drive     1011 1037 drive     root   11r     FIFO               0,13      0t0   41182 pipe
# drive     1011 1037 drive     root   12w     FIFO               0,13      0t0   41182 pipe
# drive     1011 1037 drive     root   13w     FIFO               0,13      0t0   39929 pipe
# drive     1011 1037 drive     root   14r     FIFO               0,13      0t0   41183 pipe
# drive     1011 1037 drive     root   15u     unix 0x0000000000000000      0t0   41185 /tmp/drivefs_ipc.0 type=STREAM
# drive     1011 1037 drive     root   16r     FIFO               0,13      0t0   41186 pipe
# drive     1011 1037 drive     root   17w     FIFO               0,13      0t0   41186 pipe
# drive     1011 1037 drive     root   18r     FIFO               0,13      0t0   41187 pipe
# drive     1011 1037 drive     root   19w     FIFO               0,13      0t0   41187 pipe
# drive     1011 1037 drive     root   20ur     REG               0,51    36864 1310797 /root/.config/Google/DriveFS/root_preference_sqlite.db
# drive     1011 1037 drive     root   21u      REG               0,51        0 1310821 /root/.config/Google/DriveFS/root_preference_sqlite.db-wal
# drive     1011 1037 drive     root   22ur     REG               0,51    32768 1310891 /root/.config/Google/DriveFS/root_preference_sqlite.db-shm
# drive     1011 1037 drive     root   23u  a_inode               0,14        0      18 [eventpoll]
# drive     1011 1037 drive     root   24u     unix 0x0000000000000000      0t0   41203 /tmp/drivefs_ipc.0_shell type=STREAM
# drive     1011 1037 drive     root   26ur     REG               0,51    53248 1310803 /root/.config/Google/DriveFS/experiments.db
# drive     1011 1037 drive     root   28u     IPv4             310190      0t0     TCP e8229860d1c1:41454->pl-in-f95.1e100.net:443 (ESTABLISHED)
# drive     1011 1037 drive     root   29r     FIFO               0,13      0t0   41210 pipe
# drive     1011 1037 drive     root   30w     FIFO               0,13      0t0   41210 pipe
# drive     1011 1037 drive     root   31w      REG               0,51     1911 1310892 /tmp/drive.e8229860d1c1.root.log.WARNING.20240220-140447.1011
# drive     1011 1037 drive     root   32w      REG               0,51     1911 1310900 /tmp/drive.e8229860d1c1.root.log.ERROR.20240220-140447.1011
# drive     1011 1037 drive     root   33u     unix 0x0000000000000000      0t0   42135 type=STREAM
# drive     1011 1037 drive     root   34u     unix 0x0000000000000000      0t0   42136 type=STREAM
# drive     1011 1037 drive     root   35u     IPv4              42137      0t0     TCP e8229860d1c1:40968->172.28.0.1:8009 (ESTABLISHED)
# drive     1011 1037 drive     root   36ur     REG               0,51    12288 1310814 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db
# drive     1011 1037 drive     root   37u      REG               0,51  1977632 1310903 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-wal
# drive     1011 1037 drive     root   38r     FIFO               0,13      0t0   41223 pipe
# drive     1011 1037 drive     root   39w     FIFO               0,13      0t0   41223 pipe
# drive     1011 1037 drive     root   40ur     REG               0,51    32768 1310904 /root/.config/Google/DriveFS/116273428523666932979/metrics_store_sqlite.db-shm
# drive     1011 1037 drive     root   41ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1037 drive     root   42ur     REG               0,51     8192 1310819 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db
# drive     1011 1037 drive     root   43u      REG               0,51   329632 1310907 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-wal
# drive     1011 1037 drive     root   44ur     REG               0,51    32768 1310911 /root/.config/Google/DriveFS/116273428523666932979/content_cache/chunks.db-shm
# drive     1011 1037 drive     root   45ur     REG               0,51     8192 1310890 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db
# drive     1011 1037 drive     root   46u      REG               0,51     4152 1310912 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-wal
# drive     1011 1037 drive     root   47ur     REG               0,51    32768 1310914 /root/.config/Google/DriveFS/116273428523666932979/thumbnails_cache/chunks.db-shm
# drive     1011 1037 drive     root   48u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1037 drive     root   49ur     REG               0,51    32768 1310915 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-shm
# drive     1011 1037 drive     root   50ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1037 drive     root   51u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1037 drive     root   52ur     REG               0,51    12288 1310902 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter
# drive     1011 1037 drive     root   53u      REG               0,51    41232 1310917 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-wal
# drive     1011 1037 drive     root   54ur     REG               0,51    32768 1310918 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-shm
# drive     1011 1037 drive     root   55ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1037 drive     root   56u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1037 drive     root   57ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1037 drive     root   58u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1037 drive     root   59ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1037 drive     root   60u      REG               0,51  4181832 1310906 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db-wal
# drive     1011 1037 drive     root   61ur     REG               0,51    12288 1310902 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter
# drive     1011 1037 drive     root   62u      REG               0,51    41232 1310917 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db_local_counter-wal
# drive     1011 1037 drive     root   63ur     REG               0,51    28672 1310905 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db
# drive     1011 1037 drive     root   64u      REG               0,51        0 1310920 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-wal
# drive     1011 1037 drive     root   65ur     REG               0,51    32768 1310921 /root/.config/Google/DriveFS/116273428523666932979/metadata_update_db-shm
# drive     1011 1037 drive     root   66ur     REG               0,51   569344 1310889 /root/.config/Google/DriveFS/116273428523666932979/metadata_sqlite_db
# drive     1011 1037 drive     root   67r  a_inode               0,14        0      18 inotify
# drive     1011 1037 drive     root   68ur     REG               0,51    77824 1310910 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db
# drive     1011 1037 drive     root   69u      REG               0,51        0 1310927 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-wal
# drive     1011 1037 drive     root   70ur     REG               0,51    32768 1310928 /root/.config/Google/DriveFS/116273428523666932979/mirror_sqlite.db-shm
# drive     1011 1037 drive     root   71ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1037 drive     root   72u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1037 drive     root   73ur     REG               0,51    32768 1310930 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-shm
# drive     1011 1037 drive     root   74ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1037 drive     root   75u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1037 drive     root   76ur     REG               0,51    12288 1310916 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter
# drive     1011 1037 drive     root   77u      REG               0,51    16512 1310931 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-wal
# drive     1011 1037 drive     root   78ur     REG               0,51    32768 1310932 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-shm
# drive     1011 1037 drive     root   79ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1037 drive     root   80u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1037 drive     root   81ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1037 drive     root   82u     unix 0x0000000000000000      0t0   42204 type=STREAM
# drive     1011 1037 drive     root   83u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1037 drive     root   84ur     REG               0,51   151552 1310913 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db
# drive     1011 1037 drive     root   85u      REG               0,51  2649192 1310929 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db-wal
# drive     1011 1037 drive     root   86ur     REG               0,51    12288 1310916 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter
# drive     1011 1037 drive     root   87u      REG               0,51    16512 1310931 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_sqlite.db_local_counter-wal
# drive     1011 1037 drive     root   88ur     REG               0,51    28672 1310919 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db
# drive     1011 1037 drive     root   89u      REG               0,51        0 1310933 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-wal
# drive     1011 1037 drive     root   90ur     REG               0,51    32768 1310934 /root/.config/Google/DriveFS/116273428523666932979/mirror_metadata_update_db-shm
# drive     1011 1037 drive     root   91u     unix 0x0000000000000000      0t0   42205 type=STREAM
# ...
# directory 1096                root    3u      REG               0,51     1188 1310942 /tmp/directoryprefetcher_binary.e8229860d1c1.root.log.INFO.20240220-140449.1096
# directory 1096                root    4u  a_inode               0,14        0      18 [eventpoll]
# directory 1096                root    5r     FIFO               0,13      0t0   41378 pipe
# directory 1096                root    6w     FIFO               0,13      0t0   41378 pipe
# directory 1096                root    7u  a_inode               0,14        0      18 [fanotify]
# directory 1096 1099 directory root  cwd       DIR               0,51     4096 4325382 /content
# directory 1096 1099 directory root  rtd       DIR               0,51     4096 1310732 /
# directory 1096 1099 directory root  txt       REG               0,51  2456136 6684690 /opt/google/drive/directoryprefetcher_binary
# directory 1096 1099 directory root  mem       REG                7,0          6684690 /opt/google/drive/directoryprefetcher_binary (path dev=0,51)
# directory 1096 1099 directory root    0r      CHR                1,3      0t0       5 /dev/null
# directory 1096 1099 directory root    1w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1099 directory root    2w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1099 directory root    3u      REG               0,51     1188 1310942 /tmp/directoryprefetcher_binary.e8229860d1c1.root.log.INFO.20240220-140449.1096
# directory 1096 1099 directory root    4u  a_inode               0,14        0      18 [eventpoll]
# directory 1096 1099 directory root    5r     FIFO               0,13      0t0   41378 pipe
# directory 1096 1099 directory root    6w     FIFO               0,13      0t0   41378 pipe
# directory 1096 1099 directory root    7u  a_inode               0,14        0      18 [fanotify]
# directory 1096 1100 directory root  cwd       DIR               0,51     4096 4325382 /content
# directory 1096 1100 directory root  rtd       DIR               0,51     4096 1310732 /
# directory 1096 1100 directory root  txt       REG               0,51  2456136 6684690 /opt/google/drive/directoryprefetcher_binary
# directory 1096 1100 directory root  mem       REG                7,0          6684690 /opt/google/drive/directoryprefetcher_binary (path dev=0,51)
# directory 1096 1100 directory root    0r      CHR                1,3      0t0       5 /dev/null
# directory 1096 1100 directory root    1w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1100 directory root    2w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1100 directory root    3u      REG               0,51     1188 1310942 /tmp/directoryprefetcher_binary.e8229860d1c1.root.log.INFO.20240220-140449.1096
# directory 1096 1100 directory root    4u  a_inode               0,14        0      18 [eventpoll]
# directory 1096 1100 directory root    5r     FIFO               0,13      0t0   41378 pipe
# directory 1096 1100 directory root    6w     FIFO               0,13      0t0   41378 pipe
# directory 1096 1100 directory root    7u  a_inode               0,14        0      18 [fanotify]
# directory 1096 1101 directory root  cwd       DIR               0,51     4096 4325382 /content
# directory 1096 1101 directory root  rtd       DIR               0,51     4096 1310732 /
# directory 1096 1101 directory root  txt       REG               0,51  2456136 6684690 /opt/google/drive/directoryprefetcher_binary
# directory 1096 1101 directory root  mem       REG                7,0          6684690 /opt/google/drive/directoryprefetcher_binary (path dev=0,51)
# directory 1096 1101 directory root    0r      CHR                1,3      0t0       5 /dev/null
# directory 1096 1101 directory root    1w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1101 directory root    2w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1101 directory root    3u      REG               0,51     1188 1310942 /tmp/directoryprefetcher_binary.e8229860d1c1.root.log.INFO.20240220-140449.1096
# directory 1096 1101 directory root    4u  a_inode               0,14        0      18 [eventpoll]
# directory 1096 1101 directory root    5r     FIFO               0,13      0t0   41378 pipe
# directory 1096 1101 directory root    6w     FIFO               0,13      0t0   41378 pipe
# directory 1096 1101 directory root    7u  a_inode               0,14        0      18 [fanotify]
# directory 1096 1102 directory root  cwd       DIR               0,51     4096 4325382 /content
# directory 1096 1102 directory root  rtd       DIR               0,51     4096 1310732 /
# directory 1096 1102 directory root  txt       REG               0,51  2456136 6684690 /opt/google/drive/directoryprefetcher_binary
# directory 1096 1102 directory root  mem       REG                7,0          6684690 /opt/google/drive/directoryprefetcher_binary (path dev=0,51)
# directory 1096 1102 directory root    0r      CHR                1,3      0t0       5 /dev/null
# directory 1096 1102 directory root    1w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1102 directory root    2w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 1102 directory root    3u      REG               0,51     1188 1310942 /tmp/directoryprefetcher_binary.e8229860d1c1.root.log.INFO.20240220-140449.1096
# directory 1096 1102 directory root    4u  a_inode               0,14        0      18 [eventpoll]
# directory 1096 1102 directory root    5r     FIFO               0,13      0t0   41378 pipe
# directory 1096 1102 directory root    6w     FIFO               0,13      0t0   41378 pipe
# directory 1096 1102 directory root    7u  a_inode               0,14        0      18 [fanotify]
# directory 1096 8832 directory root  cwd       DIR               0,51     4096 4325382 /content
# directory 1096 8832 directory root  rtd       DIR               0,51     4096 1310732 /
# directory 1096 8832 directory root  txt       REG               0,51  2456136 6684690 /opt/google/drive/directoryprefetcher_binary
# directory 1096 8832 directory root  mem       REG                7,0          6684690 /opt/google/drive/directoryprefetcher_binary (path dev=0,51)
# directory 1096 8832 directory root    0r      CHR                1,3      0t0       5 /dev/null
# directory 1096 8832 directory root    1w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 8832 directory root    2w      REG               0,51       89 1310940 /root/.config/Google/DriveFS/Logs/dpb.txt
# directory 1096 8832 directory root    3u      REG               0,51     1188 1310942 /tmp/directoryprefetcher_binary.e8229860d1c1.root.log.INFO.20240220-140449.1096
# directory 1096 8832 directory root    4u  a_inode               0,14        0      18 [eventpoll]
# directory 1096 8832 directory root    5r     FIFO               0,13      0t0   41378 pipe
# directory 1096 8832 directory root    6w     FIFO               0,13      0t0   41378 pipe
# directory 1096 8832 directory root    7u  a_inode               0,14        0      18 [fanotify]
# tail      1097                root  cwd       DIR               0,51     4096 4325382 /content
# tail      1097                root  rtd       DIR               0,51     4096 1310732 /
# tail      1097                root  txt       REG               0,51    68120 5636535 /usr/bin/tail
# tail      1097                root  mem       REG                7,0          5636535 /usr/bin/tail (path dev=0,51)
# tail      1097                root  mem       REG                7,0          1603426 /usr/lib/x86_64-linux-gnu/libc.so.6 (path dev=0,51)
# tail      1097                root  mem       REG                7,0          1603060 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2 (path dev=0,51)
# tail      1097                root    0r      CHR                1,3      0t0       5 /dev/null
# tail      1097                root    1w     FIFO               0,13      0t0   41375 pipe
# tail      1097                root    2w      CHR                1,3      0t0       5 /dev/null
# tail      1097                root    3r      REG               0,51   109122 1310801 /root/.config/Google/DriveFS/Logs/drive_fs.txt
# python3   1098                root  cwd       DIR               0,51     4096 4325382 /content
# python3   1098                root  rtd       DIR               0,51     4096 1310732 /
# python3   1098                root  txt       REG               0,51  5904904 1573817 /usr/bin/python3.10
# python3   1098                root  mem       REG                7,0          1573817 /usr/bin/python3.10 (path dev=0,51)
# python3   1098                root  mem       REG                7,0          5636636 /usr/lib/locale/C.utf8/LC_CTYPE (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1598509 /usr/lib/locale/locale-archive (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1603426 /usr/lib/x86_64-linux-gnu/libc.so.6 (path dev=0,51)
# python3   1098                root  mem       REG                7,0          5637187 /usr/lib/x86_64-linux-gnu/libz.so.1.2.11 (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1603566 /usr/lib/x86_64-linux-gnu/libexpat.so.1.8.7 (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1604006 /usr/lib/x86_64-linux-gnu/libm.so.6 (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1600551 /usr/lib/python3.10/lib-dynload/_json.cpython-310-x86_64-linux-gnu.so (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1602925 /usr/lib/x86_64-linux-gnu/gconv/gconv-modules.cache (path dev=0,51)
# python3   1098                root  mem       REG                7,0          1603060 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2 (path dev=0,51)
# python3   1098                root    0r     FIFO               0,13      0t0   41375 pipe
# python3   1098                root    1w      REG               0,51        0 1310941 /root/.config/Google/DriveFS/Logs/timeouts.txt
# python3   1098                root    2w      CHR                1,3      0t0       5 /dev/null
# lsof      9519                root  cwd       DIR               0,51     4096 4325382 /content
# lsof      9519                root  rtd       DIR               0,51     4096 1310732 /
# lsof      9519                root  txt       REG               0,51   167544 1573702 /usr/bin/lsof
# lsof      9519                root  mem       REG                7,0          1573702 /usr/bin/lsof (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1598509 /usr/lib/locale/locale-archive (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1604613 /usr/lib/x86_64-linux-gnu/libresolv.so.2 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          5637099 /usr/lib/x86_64-linux-gnu/libkeyutils.so.1.9 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1603976 /usr/lib/x86_64-linux-gnu/libkrb5support.so.0.1 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          5637063 /usr/lib/x86_64-linux-gnu/libcom_err.so.2.1 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1603939 /usr/lib/x86_64-linux-gnu/libk5crypto.so.3.1 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1603973 /usr/lib/x86_64-linux-gnu/libkrb5.so.3.3 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          5637146 /usr/lib/x86_64-linux-gnu/libpcre2-8.so.0.10.4 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1603772 /usr/lib/x86_64-linux-gnu/libgssapi_krb5.so.2.2 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1603426 /usr/lib/x86_64-linux-gnu/libc.so.6 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          5637156 /usr/lib/x86_64-linux-gnu/libselinux.so.1 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          5637176 /usr/lib/x86_64-linux-gnu/libtirpc.so.3.0.0 (path dev=0,51)
# lsof      9519                root  mem       REG                7,0          1603060 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2 (path dev=0,51)
# lsof      9519                root    0u      CHR              136,0      0t0       3 /dev/pts/0
# lsof      9519                root    1u      CHR              136,0      0t0       3 /dev/pts/0
# lsof      9519                root    2u      CHR              136,0      0t0       3 /dev/pts/0
# lsof      9519                root    3r      DIR               0,59        0       1 /proc
# lsof      9519                root    4r      DIR               0,59        0  325428 /proc/9519/fd
# lsof      9519                root    5w     FIFO               0,13      0t0  325641 pipe
# lsof      9519                root    6r     FIFO               0,13      0t0  325642 pipe
# lsof      9520                root  cwd       DIR               0,51     4096 4325382 /content
# lsof      9520                root  rtd       DIR               0,51     4096 1310732 /
# lsof      9520                root  txt       REG               0,51   167544 1573702 /usr/bin/lsof
# lsof      9520                root  mem       REG                7,0          1573702 /usr/bin/lsof (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1598509 /usr/lib/locale/locale-archive (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1604613 /usr/lib/x86_64-linux-gnu/libresolv.so.2 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          5637099 /usr/lib/x86_64-linux-gnu/libkeyutils.so.1.9 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1603976 /usr/lib/x86_64-linux-gnu/libkrb5support.so.0.1 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          5637063 /usr/lib/x86_64-linux-gnu/libcom_err.so.2.1 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1603939 /usr/lib/x86_64-linux-gnu/libk5crypto.so.3.1 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1603973 /usr/lib/x86_64-linux-gnu/libkrb5.so.3.3 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          5637146 /usr/lib/x86_64-linux-gnu/libpcre2-8.so.0.10.4 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1603772 /usr/lib/x86_64-linux-gnu/libgssapi_krb5.so.2.2 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1603426 /usr/lib/x86_64-linux-gnu/libc.so.6 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          5637156 /usr/lib/x86_64-linux-gnu/libselinux.so.1 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          5637176 /usr/lib/x86_64-linux-gnu/libtirpc.so.3.0.0 (path dev=0,51)
# lsof      9520                root  mem       REG                7,0          1603060 /usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2 (path dev=0,51)
# lsof      9520                root    4r     FIFO               0,13      0t0  325641 pipe
# lsof      9520                root    7w     FIFO               0,13      0t0  325642 pipe
